# %% [markdown]
# [Can GANs Learn the Stylized Facts of Financial Time Series?
# ](https://arxiv.org/pdf/2410.09850)
#
# [Generative Adversarial Networks in finance: an overview
# ](https://arxiv.org/abs/2106.06364)
